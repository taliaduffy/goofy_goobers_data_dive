# %% [markdown]
# ## EDA on some gambling data!

# %%
import pandas as pd

# %%
df = pd.read_csv("restructuring_revenue_data.csv")

# %%
df
# Out:
#       Municipality                           Establishment  License Number  \
# 0         Abingdon  ABBE LANES BOWLING & ENTERTAINMENT LLC     180702343.0
# 1         Abingdon                    AT'S Pub & Sport LLC     210700197.0
# 2         Abingdon                 JP FOOD & LIQUOR , INC.     220701041.0
# 3         Abingdon                   MA & PA LIQUOR'S INC.     200702153.0
# 4         Abingdon                   Skeeter's Place, Inc.     120704053.0
# ...            ...                                     ...             ...
# 10307         Zion                   Northpointe Inn, Inc.     150702937.0
# 10308         Zion                          Qu's Place LLC     190700309.0
# 10309         Zion                   SDD ENTERTAINMENT LLC     150703662.0
# 10310         Zion                   SDD ENTERTAINMENT LLC     150703712.0
# 10311         Zion                  STAR 6855 INCORPORATED     170702931.0
#
# ...
